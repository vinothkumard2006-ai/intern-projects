# %%
import pandas as pd
import numpy as np

# %%
sellerMappingTable=pd.read_excel(r"C:\Users\vinot\OneDrive\Desktop\project\Seller Mapping Table.xlsx.xlsx")
sellerMappingTable
# Out:
#                   Ssellers_name           homologated_sellers
# 0                Cocoblu Retail           BJ's Wholesale Club
# 1      RK World Infocom Pvt Ltd                American Eagle
# 2    Appario Retail Private Ltd                      Tapestry
# 3              RetailEZ Pvt Ltd           Wakefern / ShopRite
# 4                 ETrade Online          Harbor Freight Tools
# ..                          ...                           ...
# 898            Hydroshell India  Barnes and Noble Booksellers
# 899                 KT FASHIONS           J.C. Penney Company
# 900               Shoplite 0000                      Tapestry
# 901                 Bestbuybook        Sprouts Farmers Market
# 902                  Seetabooks                  Advance Auto
#
# [903 rows x 2 columns]

# %%
dup=sellerMappingTable[sellerMappingTable['Ssellers_name'].duplicated(keep=False)]
dup
# Out:
#     Ssellers_name     homologated_sellers
# 100        Seller  Sprouts Farmers Market
# 301        Seller                7-Eleven
# 602        Seller      Tractor Supply Co.

# %%
sellerMappingTable = sellerMappingTable.drop_duplicates(subset=['Ssellers_name'],keep='first')

# %%
sellerMappingTable['Ssellers_name'].isna().sum()
# Out:
# np.int64(0)

# %%
sellerMappingTable.shape
# Out:
# (901, 2)

# %%
CategoryMappingtable=pd.read_json(r"C:\Users\vinot\OneDrive\Desktop\project\Category Mapping Table.json.json",lines=True)
CategoryMappingtable
# Out:
#                      PL      sku
# 0      DELL0X_PC_Laptop  0X749QB
# 1     DELL75_PC_Monitor  75X62BB
# 2        DELLDF_SUP_TON   DF627B
# 3            HP4Z_PH_LJ   4ZB96A
# 4      DELL0R_PC_Laptop  0R0N0QB
# ...                 ...      ...
# 1593     DELL4K_SUP_INK  4KB93BB
# 1594     DELLX2_SUP_TON   X2231B
# 1595       HPB3_SUP_INK   B3P21A
# 1596  DELL78_PC_Desktop  78X20QB
# 1597       HPCF_SUP_TON   CF364A
#
# [1598 rows x 2 columns]

# %%
PLtable=pd.read_json(r"C:\Users\vinot\OneDrive\Desktop\project\PL Table.json.json",lines=True)
PLtable
# Out:
#           sku                 PL
# 0     0X749QB   DELL0X_PC_Laptop
# 1     75X62BB  DELL75_PC_Monitor
# 2      DF627B     DELLDF_SUP_TON
# 3      4ZB96A         HP4Z_PH_LJ
# 4     0R0N0QB   DELL0R_PC_Laptop
# ...       ...                ...
# 1593  4KB93BB     DELL4K_SUP_INK
# 1594   X2231B     DELLX2_SUP_TON
# 1595   B3P21A       HPB3_SUP_INK
# 1596  78X20QB  DELL78_PC_Desktop
# 1597   CF364A       HPCF_SUP_TON
#
# [1598 rows x 2 columns]

# %%
PLtable["PL"].unique
# Out:
# <bound method Series.unique of 0        DELL0X_PC_Laptop
# 1       DELL75_PC_Monitor
# 2          DELLDF_SUP_TON
# 3              HP4Z_PH_LJ
# 4        DELL0R_PC_Laptop
#               ...
# 1593       DELL4K_SUP_INK
# 1594       DELLX2_SUP_TON
# 1595         HPB3_SUP_INK
# 1596    DELL78_PC_Desktop
# 1597         HPCF_SUP_TON
# Name: PL, Length: 1598, dtype: object>

# %%
SKUtable=pd.read_xml(r"C:\Users\vinot\OneDrive\Desktop\project\SKU Table.xml.xml")
SKUtable
# Out:
#               PN      Sku
# 0        Pib01a1  0X749QB
# 1        Pib01a2  75X62BB
# 2        Pib01a3   DF627B
# 3        Pib01a4   4ZB96A
# 4        Pib01a5  0R0N0QB
# ...          ...      ...
# 1593  Pib01a1594  4KB93BB
# 1594  Pib01a1595   X2231B
# 1595  Pib01a1596   B3P21A
# 1596  Pib01a1597  78X20QB
# 1597  Pib01a1598   CF364A
#
# [1598 rows x 2 columns]

# %%
import yaml 

with open(r"C:\Users\vinot\OneDrive\Desktop\project\Price List Table.yaml.yaml") as f:
    data = yaml.safe_load(f)
    Price_list_table=pd.DataFrame(data)
Price_list_table
# Out:
#          MAP                 PL      sku
# 0     106684   DELL0X_PC_Laptop  0X749QB
# 1      35611  DELL75_PC_Monitor  75X62BB
# 2      29914     DELLDF_SUP_TON   DF627B
# 3      39258         HP4Z_PH_LJ   4ZB96A
# 4     139670   DELL0R_PC_Laptop  0R0N0QB
# ...      ...                ...      ...
# 1593    3565     DELL4K_SUP_INK  4KB93BB
# 1594    6716     DELLX2_SUP_TON   X2231B
# 1595    6868       HPB3_SUP_INK   B3P21A
# 1596   47937  DELL78_PC_Desktop  78X20QB
# 1597   28243       HPCF_SUP_TON   CF364A
#
# [1598 rows x 3 columns]

# %%
PLtable.head()
# Out:
#        sku                 PL
# 0  0X749QB   DELL0X_PC_Laptop
# 1  75X62BB  DELL75_PC_Monitor
# 2   DF627B     DELLDF_SUP_TON
# 3   4ZB96A         HP4Z_PH_LJ
# 4  0R0N0QB   DELL0R_PC_Laptop

# %%
#category
def get_category(pl):
    if '_PC_' in pl:
        return 'PC'
    elif '_SUP_' in pl:
        return 'Supplies'
    elif '_PH_' in pl:
        return 'Print Hardware'
    else:
        return 'Others'

#sub category
def get_sub_category(pl):
    if 'Laptop' in pl:
        return 'Laptop'
    elif 'Monitor' in pl:
        return 'Monitor'
    elif 'Desktop' in pl:
        return 'Desktop'
    elif 'INK' in pl:
        return 'Ink'
    elif 'TON' in pl:
        return 'Toner'
    elif 'LJ' in pl:
        return 'Laserjet'
    elif 'IJ' in pl:
        return 'Inkjet'
    elif 'SJ' in pl:
        return 'Single function Inkjet'
    elif 'UNK' in pl:
        return 'Unknown'
    else:
        return 'Others'

PLtable['Category'] = PLtable['PL'].apply(get_category)
PLtable['SUB_CATEGORY'] = PLtable['PL'].apply(get_sub_category)

# %%
PLtable['Category'].unique()
# Out:
# array(['PC', 'Supplies', 'Print Hardware'], dtype=object)

# %%
PLtable['SUB_CATEGORY'].unique()
# Out:
# array(['Laptop', 'Monitor', 'Toner', 'Laserjet', 'Inkjet', 'Desktop',
#        'Ink', 'Unknown', 'Single function Inkjet'], dtype=object)

# %%
PLtable.drop(PLtable[PLtable['SUB_CATEGORY'].isin(['Unknown','Single function Inkjet'])].index,inplace=True)

# %%
PLtable.head()
# Out:
#        sku                 PL        Category SUB_CATEGORY
# 0  0X749QB   DELL0X_PC_Laptop              PC       Laptop
# 1  75X62BB  DELL75_PC_Monitor              PC      Monitor
# 2   DF627B     DELLDF_SUP_TON        Supplies        Toner
# 3   4ZB96A         HP4Z_PH_LJ  Print Hardware     Laserjet
# 4  0R0N0QB   DELL0R_PC_Laptop              PC       Laptop

# %%
Price_list_table.head()
# Out:
#       MAP                 PL      sku
# 0  106684   DELL0X_PC_Laptop  0X749QB
# 1   35611  DELL75_PC_Monitor  75X62BB
# 2   29914     DELLDF_SUP_TON   DF627B
# 3   39258         HP4Z_PH_LJ   4ZB96A
# 4  139670   DELL0R_PC_Laptop  0R0N0QB

# %%
def get_brand(pl):
    if pl.startswith('HP'):
       return 'HP'
    elif pl.startswith('DELL'):
       return 'DELL'
    else:
        return 'Others'
Price_list_table['BRAND'] =Price_list_table['PL'].apply(get_brand)

# %%
Price_list_table.tail()
# Out:
#         MAP                 PL      sku BRAND
# 1593   3565     DELL4K_SUP_INK  4KB93BB  DELL
# 1594   6716     DELLX2_SUP_TON   X2231B  DELL
# 1595   6868       HPB3_SUP_INK   B3P21A    HP
# 1596  47937  DELL78_PC_Desktop  78X20QB  DELL
# 1597  28243       HPCF_SUP_TON   CF364A    HP

# %%
Price_list_table['sku'] = Price_list_table['sku'].astype(str).str.strip().str.upper()
PLtable['sku'] = PLtable['sku'].astype(str).str.strip().str.upper()

# %%
merge_table = Price_list_table.merge(PLtable[['sku','Category','SUB_CATEGORY']],
                                     on='sku',how='left')
merge_table
# Out:
#          MAP                 PL      sku BRAND        Category SUB_CATEGORY
# 0     106684   DELL0X_PC_Laptop  0X749QB  DELL              PC       Laptop
# 1      35611  DELL75_PC_Monitor  75X62BB  DELL              PC      Monitor
# 2      29914     DELLDF_SUP_TON   DF627B  DELL        Supplies        Toner
# 3      39258         HP4Z_PH_LJ   4ZB96A    HP  Print Hardware     Laserjet
# 4     139670   DELL0R_PC_Laptop  0R0N0QB  DELL              PC       Laptop
# ...      ...                ...      ...   ...             ...          ...
# 1601    3565     DELL4K_SUP_INK  4KB93BB  DELL        Supplies          Ink
# 1602    6716     DELLX2_SUP_TON   X2231B  DELL        Supplies        Toner
# 1603    6868       HPB3_SUP_INK   B3P21A    HP        Supplies          Ink
# 1604   47937  DELL78_PC_Desktop  78X20QB  DELL              PC      Desktop
# 1605   28243       HPCF_SUP_TON   CF364A    HP        Supplies        Toner
#
# [1606 rows x 6 columns]

# %%
merge_table.isna().sum()
# Out:
# MAP              0
# PL               0
# sku              0
# BRAND            0
# Category        48
# SUB_CATEGORY    48
# dtype: int64

# %%
merge_table.dropna(inplace=True)

# %%
lpp_percentage ={
    'Laptop' :{'HP':0.0340,'DELL':0.0780},
    'Monitor':{'HP':0.0120,'DELL':0.0560},
    'Toner':{'HP':0.0910,'DELL':0.0230},
    'Laserjet':{'HP':0.0650,'DELL':0.0350},
    'Inkjet':{'HP':0.0120,'DELL':0.0560},
    'Desktop':{'HP':0.0910,'DELL':0.0230},
    'Ink':{'HP':0.0650,'DELL':0.0350}
}

#Lpp logic column
def calculate_lpp(row):
    sub = row['SUB_CATEGORY']
    brand = row['BRAND']
    map_price = row['MAP']

    if sub in lpp_percentage and brand in lpp_percentage[sub]:
        return map_price*(1-lpp_percentage[sub][brand])
    else:
        return map_price

merge_table['LPP'] = merge_table.apply(calculate_lpp, axis=1)

# %%
merge_table.isna().sum()
# Out:
# MAP             0
# PL              0
# sku             0
# BRAND           0
# Category        0
# SUB_CATEGORY    0
# LPP             0
# dtype: int64

# %%
merge_table.head()
# Out:
#       MAP                 PL      sku BRAND        Category SUB_CATEGORY  \
# 0  106684   DELL0X_PC_Laptop  0X749QB  DELL              PC       Laptop
# 1   35611  DELL75_PC_Monitor  75X62BB  DELL              PC      Monitor
# 2   29914     DELLDF_SUP_TON   DF627B  DELL        Supplies        Toner
# 3   39258         HP4Z_PH_LJ   4ZB96A    HP  Print Hardware     Laserjet
# 4  139670   DELL0R_PC_Laptop  0R0N0QB  DELL              PC       Laptop
#
#           LPP
# 0   98362.648
# 1   33616.784
# 2   29225.978
# 3   36706.230
# 4  128775.740

# %%
from datetime import datetime

merge_table['datetime']=datetime.now() ##this also use...

# %%
## merge_table['date'] = pd.Timestamp.now().date() use this also

# %%
##merge_table['Time'] = pd.Timestamp.now().time()  use this also

# %%
merge_table.tail(10)
# Out:
#         MAP                 PL      sku BRAND  Category SUB_CATEGORY  \
# 1596   4836     DELLD3_SUP_INK  D3Q18BB  DELL  Supplies          Ink
# 1597  50999    HP63_PC_Desktop  635X7PA    HP        PC      Desktop
# 1598   1460       HPW1_SUP_TON   W1580X    HP  Supplies        Toner
# 1599  77429     HP77_PC_Laptop  77S54PA    HP        PC       Laptop
# 1600  42427   DELL0E_PC_Laptop  0E4N8QB  DELL        PC       Laptop
# 1601   3565     DELL4K_SUP_INK  4KB93BB  DELL  Supplies          Ink
# 1602   6716     DELLX2_SUP_TON   X2231B  DELL  Supplies        Toner
# 1603   6868       HPB3_SUP_INK   B3P21A    HP  Supplies          Ink
# 1604  47937  DELL78_PC_Desktop  78X20QB  DELL        PC      Desktop
# 1605  28243       HPCF_SUP_TON   CF364A    HP  Supplies        Toner
#
#             LPP                   datetime
# 1596   4666.740 2026-02-14 12:52:00.384022
# 1597  46358.091 2026-02-14 12:52:00.384022
# 1598   1327.140 2026-02-14 12:52:00.384022
# 1599  74796.414 2026-02-14 12:52:00.384022
# 1600  39117.694 2026-02-14 12:52:00.384022
# 1601   3440.225 2026-02-14 12:52:00.384022
# 1602   6561.532 2026-02-14 12:52:00.384022
# 1603   6421.580 2026-02-14 12:52:00.384022
# 1604  46834.449 2026-02-14 12:52:00.384022
# 1605  25672.887 2026-02-14 12:52:00.384022

# %%
def assign_quarter(dt):
   month = dt.month

   if month in [11,12,1]:
       return 'Q1(Nov-Jan)'       ## nov-jan
   elif month in [2,3,4]:
       return 'Q2(Feb-Apr)'       ##feb-april
   elif month in [5,6,7]:
       return 'Q3(May-Jul)'       ##may-july
   elif month in [8,9,10]:
       return 'Q4(Aug-Oct)'       ##aug-oct

merge_table['Season_Name'] = merge_table['datetime'].apply(assign_quarter)

# %%
merge_table.tail()
# Out:
#         MAP                 PL      sku BRAND  Category SUB_CATEGORY  \
# 1601   3565     DELL4K_SUP_INK  4KB93BB  DELL  Supplies          Ink
# 1602   6716     DELLX2_SUP_TON   X2231B  DELL  Supplies        Toner
# 1603   6868       HPB3_SUP_INK   B3P21A    HP  Supplies          Ink
# 1604  47937  DELL78_PC_Desktop  78X20QB  DELL        PC      Desktop
# 1605  28243       HPCF_SUP_TON   CF364A    HP  Supplies        Toner
#
#             LPP                   datetime  Season_Name
# 1601   3440.225 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1602   6561.532 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1603   6421.580 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1604  46834.449 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1605  25672.887 2026-02-14 12:52:00.384022  Q2(Feb-Apr)

# %%
merge_table.isna().sum()
# Out:
# MAP             0
# PL              0
# sku             0
# BRAND           0
# Category        0
# SUB_CATEGORY    0
# LPP             0
# datetime        0
# Season_Name     0
# dtype: int64

# %%
offer_table = pd.read_excel(r"C:\Users\vinot\OneDrive\Desktop\project\offertable.xlsx")
offer_table
# Out:
#          Category     Q1 (Nov-Jan)        Q2 (Feb-Apr)      Q3 (May-Jul)  \
# 0          Supply      10% off ink        $2 off toner      5% off toner
# 1  Print Hardware  15% off ink jet  Free setup service   2% off scanners
# 2              PC  $10 off laptops    Free accessories  Free accessories
#
#          Q4 (Aug-Oct)
# 0        20% off  ink
# 1  $10 off laser jet
# 2            15 % off

# %%
## melt offer logic(reshape the table)
offer_melted = offer_table.melt(
    id_vars=['Category'],
    var_name='Season_Name',
    value_name='offers')

offer_melted['Category'] = offer_melted['Category']
offer_melted['Season_Name'] = offer_melted['Season_Name']
offer_melted
# Out:
#           Category   Season_Name              offers
# 0           Supply  Q1 (Nov-Jan)         10% off ink
# 1   Print Hardware  Q1 (Nov-Jan)     15% off ink jet
# 2               PC  Q1 (Nov-Jan)     $10 off laptops
# 3           Supply  Q2 (Feb-Apr)        $2 off toner
# 4   Print Hardware  Q2 (Feb-Apr)  Free setup service
# 5               PC  Q2 (Feb-Apr)    Free accessories
# 6           Supply  Q3 (May-Jul)        5% off toner
# 7   Print Hardware  Q3 (May-Jul)     2% off scanners
# 8               PC  Q3 (May-Jul)    Free accessories
# 9           Supply  Q4 (Aug-Oct)        20% off  ink
# 10  Print Hardware  Q4 (Aug-Oct)  $10 off laser jet
# 11              PC  Q4 (Aug-Oct)            15 % off

# %%
Promotion_sku = pd.read_excel(r"C:\Users\vinot\OneDrive\Desktop\project\Promotiontable.xlsx")
Promotion_sku
# Out:
#       Promotional SKUs
# 0    For the SKU Below
# 1               G0L15B
# 2              7Y4T6QB
# 3              4K0V8PA
# 4              385Z7PA
# ..                 ...
# 96              7KW56A
# 97              X2214B
# 98             8F8Z3PA
# 99             77S54PA
# 100             B3P21A
#
# [101 rows x 1 columns]

# %%
Promotion_sku = Promotion_sku.drop(index=0)
Promotion_sku
# Out:
#     Promotional SKUs
# 1             G0L15B
# 2            7Y4T6QB
# 3            4K0V8PA
# 4            385Z7PA
# 5            T6M05AA
# ..               ...
# 96            7KW56A
# 97            X2214B
# 98           8F8Z3PA
# 99           77S54PA
# 100           B3P21A
#
# [100 rows x 1 columns]

# %%
promo_merge_table = merge_table[merge_table['sku'].isin(Promotion_sku['Promotional SKUs'])]
promo_merge_table
# Out:
#          MAP                 PL      sku BRAND        Category SUB_CATEGORY  \
# 8       9900     DELLG0_SUP_INK   G0L15B  DELL        Supplies          Ink
# 53     67545  DELL7Y_PC_Desktop  7Y4T6QB  DELL              PC      Desktop
# 60      1080       HP4K_SUP_INK  4K0V8PA    HP        Supplies          Ink
# 65     50366    HP38_PC_Desktop  385Z7PA    HP              PC      Desktop
# 75      2478       HPT6_SUP_INK  T6M05AA    HP        Supplies          Ink
# ...      ...                ...      ...   ...             ...          ...
# 1558   58632         HP7K_PH_LJ   7KW56A    HP  Print Hardware     Laserjet
# 1576    1049     DELLX2_SUP_TON   X2214B  DELL        Supplies        Toner
# 1582  239399     HP8F_PC_Laptop  8F8Z3PA    HP              PC       Laptop
# 1599   77429     HP77_PC_Laptop  77S54PA    HP              PC       Laptop
# 1603    6868       HPB3_SUP_INK   B3P21A    HP        Supplies          Ink
#
#              LPP                   datetime  Season_Name
# 8       9553.500 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 53     65991.465 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 60      1009.800 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 65     45782.694 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 75      2316.930 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# ...          ...                        ...          ...
# 1558   54820.920 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1576    1024.873 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1582  231259.434 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1599   74796.414 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
# 1603    6421.580 2026-02-14 12:52:00.384022  Q2(Feb-Apr)
#
# [96 rows x 9 columns]

# %%
promo_merge_table.columns
# Out:
# Index(['MAP', 'PL', 'sku', 'BRAND', 'Category', 'SUB_CATEGORY', 'LPP',
#        'datetime', 'Season_Name'],
#       dtype='object')

# %%
offer_melted.columns
# Out:
# Index(['Category', 'Season_Name', 'offers'], dtype='object')

# %%
for df in [promo_merge_table,offer_melted]:
    df['Category'] = df['Category'].str.strip().str.upper()
    df['Season_Name'] = df['Season_Name'].str.replace(' ', '')
# Out:
# C:\Users\vinot\AppData\Local\Temp\ipykernel_14304\3267790912.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category'] = df['Category'].str.strip().str.upper()
# C:\Users\vinot\AppData\Local\Temp\ipykernel_14304\3267790912.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Season_Name'] = df['Season_Name'].str.replace(' ', '')

# %%
print(promo_merge_table['Category'].unique())
print(offer_melted['Category'].unique())
print(promo_merge_table['Season_Name'].unique())
print(offer_melted['Season_Name'].unique())
# Out:
# ['SUPPLIES' 'PC' 'PRINT HARDWARE']
# ['SUPPLY' 'PRINT HARDWARE' 'PC']
# ['Q2(Feb-Apr)']
# ['Q1(Nov-Jan)' 'Q2(Feb-Apr)' 'Q3(May-Jul)' 'Q4(Aug-Oct)']

# %%
promo_merge_table['Category'] = promo_merge_table['Category'].replace({'SUPPLIES': 'SUPPLY'})
# Out:
# C:\Users\vinot\AppData\Local\Temp\ipykernel_14304\251335943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   promo_merge_table['Category'] = promo_merge_table['Category'].replace({'SUPPLIES': 'SUPPLY'})

# %%
filtered_Promotion_sku=promo_merge_table.merge(offer_melted[['Category','Season_Name','offers']],
                                     on=['Category','Season_Name'],how='left')

# %%
filtered_Promotion_sku
# Out:
#        MAP                 PL      sku BRAND        Category SUB_CATEGORY  \
# 0     9900     DELLG0_SUP_INK   G0L15B  DELL          SUPPLY          Ink
# 1    67545  DELL7Y_PC_Desktop  7Y4T6QB  DELL              PC      Desktop
# 2     1080       HP4K_SUP_INK  4K0V8PA    HP          SUPPLY          Ink
# 3    50366    HP38_PC_Desktop  385Z7PA    HP              PC      Desktop
# 4     2478       HPT6_SUP_INK  T6M05AA    HP          SUPPLY          Ink
# ..     ...                ...      ...   ...             ...          ...
# 91   58632         HP7K_PH_LJ   7KW56A    HP  PRINT HARDWARE     Laserjet
# 92    1049     DELLX2_SUP_TON   X2214B  DELL          SUPPLY        Toner
# 93  239399     HP8F_PC_Laptop  8F8Z3PA    HP              PC       Laptop
# 94   77429     HP77_PC_Laptop  77S54PA    HP              PC       Laptop
# 95    6868       HPB3_SUP_INK   B3P21A    HP          SUPPLY          Ink
#
#            LPP                   datetime  Season_Name              offers
# 0     9553.500 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# 1    65991.465 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 2     1009.800 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# 3    45782.694 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 4     2316.930 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# ..         ...                        ...          ...                 ...
# 91   54820.920 2026-02-14 12:52:00.384022  Q2(Feb-Apr)  Free setup service
# 92    1024.873 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# 93  231259.434 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 94   74796.414 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 95    6421.580 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
#
# [96 rows x 10 columns]

# %%
filtered_Promotion_sku.isna().sum()
# Out:
# MAP             0
# PL              0
# sku             0
# BRAND           0
# Category        0
# SUB_CATEGORY    0
# LPP             0
# datetime        0
# Season_Name     0
# offers          0
# dtype: int64

# %%
def calculate_promo_value(row):
    promo = str(row['offers']).lower()
    map_price = row['MAP']

    if '%' in promo:
        percent = float(promo.split('%')[0])
        return map_price*(percent/100)

    elif '$' in promo:
        value = float(promo.replace('$','').split()[0])
        return value

    elif 'free' in promo:
        return 0

    else:
        return 0


filtered_Promotion_sku['Promotion_value'] = filtered_Promotion_sku.apply(calculate_promo_value,axis=1)

filtered_Promotion_sku['Promotion_value'] = filtered_Promotion_sku['Promotion_value'].round(2)

# %%
filtered_Promotion_sku
# Out:
#        MAP                 PL      sku BRAND        Category SUB_CATEGORY  \
# 0     9900     DELLG0_SUP_INK   G0L15B  DELL          SUPPLY          Ink
# 1    67545  DELL7Y_PC_Desktop  7Y4T6QB  DELL              PC      Desktop
# 2     1080       HP4K_SUP_INK  4K0V8PA    HP          SUPPLY          Ink
# 3    50366    HP38_PC_Desktop  385Z7PA    HP              PC      Desktop
# 4     2478       HPT6_SUP_INK  T6M05AA    HP          SUPPLY          Ink
# ..     ...                ...      ...   ...             ...          ...
# 91   58632         HP7K_PH_LJ   7KW56A    HP  PRINT HARDWARE     Laserjet
# 92    1049     DELLX2_SUP_TON   X2214B  DELL          SUPPLY        Toner
# 93  239399     HP8F_PC_Laptop  8F8Z3PA    HP              PC       Laptop
# 94   77429     HP77_PC_Laptop  77S54PA    HP              PC       Laptop
# 95    6868       HPB3_SUP_INK   B3P21A    HP          SUPPLY          Ink
#
#            LPP                   datetime  Season_Name              offers  \
# 0     9553.500 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# 1    65991.465 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 2     1009.800 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# 3    45782.694 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 4     2316.930 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# ..         ...                        ...          ...                 ...
# 91   54820.920 2026-02-14 12:52:00.384022  Q2(Feb-Apr)  Free setup service
# 92    1024.873 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
# 93  231259.434 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 94   74796.414 2026-02-14 12:52:00.384022  Q2(Feb-Apr)    Free accessories
# 95    6421.580 2026-02-14 12:52:00.384022  Q2(Feb-Apr)        $2 off toner
#
#     Promotion_value
# 0               2.0
# 1               0.0
# 2               2.0
# 3               0.0
# 4               2.0
# ..              ...
# 91              0.0
# 92              2.0
# 93              0.0
# 94              0.0
# 95              2.0
#
# [96 rows x 11 columns]

# %% [markdown]
# # Finally all Tables

# %%
SKUtable.columns=SKUtable.columns.str.strip().str.upper()
SKUtable
# Out:
#               PN      SKU
# 0        Pib01a1  0X749QB
# 1        Pib01a2  75X62BB
# 2        Pib01a3   DF627B
# 3        Pib01a4   4ZB96A
# 4        Pib01a5  0R0N0QB
# ...          ...      ...
# 1593  Pib01a1594  4KB93BB
# 1594  Pib01a1595   X2231B
# 1595  Pib01a1596   B3P21A
# 1596  Pib01a1597  78X20QB
# 1597  Pib01a1598   CF364A
#
# [1598 rows x 2 columns]

# %%
PLtable.columns=PLtable.columns.str.strip().str.upper()
PL_Table=PLtable[['PL', 'SKU', 'SUB_CATEGORY']]
PL_Table
# Out:
#                      PL      SKU SUB_CATEGORY
# 0      DELL0X_PC_Laptop  0X749QB       Laptop
# 1     DELL75_PC_Monitor  75X62BB      Monitor
# 2        DELLDF_SUP_TON   DF627B        Toner
# 3            HP4Z_PH_LJ   4ZB96A     Laserjet
# 4      DELL0R_PC_Laptop  0R0N0QB       Laptop
# ...                 ...      ...          ...
# 1593     DELL4K_SUP_INK  4KB93BB          Ink
# 1594     DELLX2_SUP_TON   X2231B        Toner
# 1595       HPB3_SUP_INK   B3P21A          Ink
# 1596  DELL78_PC_Desktop  78X20QB      Desktop
# 1597       HPCF_SUP_TON   CF364A        Toner
#
# [1550 rows x 3 columns]

# %%
merge_table.columns=merge_table.columns.str.strip().str.upper()
Price_List_Table = merge_table[['PL','SKU','MAP','LPP']]
Price_List_Table
# Out:
#                      PL      SKU     MAP         LPP
# 0      DELL0X_PC_Laptop  0X749QB  106684   98362.648
# 1     DELL75_PC_Monitor  75X62BB   35611   33616.784
# 2        DELLDF_SUP_TON   DF627B   29914   29225.978
# 3            HP4Z_PH_LJ   4ZB96A   39258   36706.230
# 4      DELL0R_PC_Laptop  0R0N0QB  139670  128775.740
# ...                 ...      ...     ...         ...
# 1601     DELL4K_SUP_INK  4KB93BB    3565    3440.225
# 1602     DELLX2_SUP_TON   X2231B    6716    6561.532
# 1603       HPB3_SUP_INK   B3P21A    6868    6421.580
# 1604  DELL78_PC_Desktop  78X20QB   47937   46834.449
# 1605       HPCF_SUP_TON   CF364A   28243   25672.887
#
# [1558 rows x 4 columns]

# %%
sellerMappingTable = sellerMappingTable.rename(columns={'Ssellers_name':'Seller_Name', 'homologated_sellers':'Homologated_Name'})
Seller_Mapping_Table = sellerMappingTable
Seller_Mapping_Table
# Out:
#                     Seller_Name              Homologated_Name
# 0                Cocoblu Retail           BJ's Wholesale Club
# 1      RK World Infocom Pvt Ltd                American Eagle
# 2    Appario Retail Private Ltd                      Tapestry
# 3              RetailEZ Pvt Ltd           Wakefern / ShopRite
# 4                 ETrade Online          Harbor Freight Tools
# ..                          ...                           ...
# 898            Hydroshell India  Barnes and Noble Booksellers
# 899                 KT FASHIONS           J.C. Penney Company
# 900               Shoplite 0000                      Tapestry
# 901                 Bestbuybook        Sprouts Farmers Market
# 902                  Seetabooks                  Advance Auto
#
# [901 rows x 2 columns]

# %%
Category_Mapping_Table = PLtable
Category_Mapping_Table
# Out:
#           SKU                 PL        CATEGORY SUB_CATEGORY
# 0     0X749QB   DELL0X_PC_Laptop              PC       Laptop
# 1     75X62BB  DELL75_PC_Monitor              PC      Monitor
# 2      DF627B     DELLDF_SUP_TON        Supplies        Toner
# 3      4ZB96A         HP4Z_PH_LJ  Print Hardware     Laserjet
# 4     0R0N0QB   DELL0R_PC_Laptop              PC       Laptop
# ...       ...                ...             ...          ...
# 1593  4KB93BB     DELL4K_SUP_INK        Supplies          Ink
# 1594   X2231B     DELLX2_SUP_TON        Supplies        Toner
# 1595   B3P21A       HPB3_SUP_INK        Supplies          Ink
# 1596  78X20QB  DELL78_PC_Desktop              PC      Desktop
# 1597   CF364A       HPCF_SUP_TON        Supplies        Toner
#
# [1550 rows x 4 columns]

# %%
Promotion_Table = filtered_Promotion_sku[[ 'PL', 'sku', 'Season_Name','Promotion_value']]
Promotion_Table
# Out:
#                    PL      sku  Season_Name  Promotion_value
# 0      DELLG0_SUP_INK   G0L15B  Q2(Feb-Apr)              2.0
# 1   DELL7Y_PC_Desktop  7Y4T6QB  Q2(Feb-Apr)              0.0
# 2        HP4K_SUP_INK  4K0V8PA  Q2(Feb-Apr)              2.0
# 3     HP38_PC_Desktop  385Z7PA  Q2(Feb-Apr)              0.0
# 4        HPT6_SUP_INK  T6M05AA  Q2(Feb-Apr)              2.0
# ..                ...      ...          ...              ...
# 91         HP7K_PH_LJ   7KW56A  Q2(Feb-Apr)              0.0
# 92     DELLX2_SUP_TON   X2214B  Q2(Feb-Apr)              2.0
# 93     HP8F_PC_Laptop  8F8Z3PA  Q2(Feb-Apr)              0.0
# 94     HP77_PC_Laptop  77S54PA  Q2(Feb-Apr)              0.0
# 95       HPB3_SUP_INK   B3P21A  Q2(Feb-Apr)              2.0
#
# [96 rows x 4 columns]

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://root:Root%40123@127.0.0.1:3306/violationdb")
conn=engine.connect()
print("Connected successfully")
# Out:
# Connected successfully

# %%
tables = {
    "sku_table": SKUtable,
    "category_mapping": Category_Mapping_Table,
    "price_list": Price_List_Table,
    "seller_mapping": Seller_Mapping_Table,
    "promotion_table":Promotion_Table
}

for name, df in tables.items():
    df.columns = df.columns.str.strip().str.upper()
    df.to_sql(name=name, con=engine,
if_exists='replace', index=False)
    print(name, "uploaded")
# Out:
# sku_table uploaded
# category_mapping uploaded
# price_list uploaded
# seller_mapping uploaded
# promotion_table uploaded
